# %%
# !pip install transformers torch torchvision
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.31.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 58.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 855.6 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Paths to ZIP files in Drive
zip1 = "/content/drive/MyDrive/all_videos1.zip"
zip2 = "/content/drive/MyDrive/all_videos2.zip"

# Where to extract them
dest1 = "/content/frames_unzip1"
dest2 = "/content/frames_unzip2"

# Extract
for zip_path, dest in [(zip1, dest1), (zip2, dest2)]:
    os.makedirs(dest, exist_ok=True)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(dest)

print("✅ Both ZIPs extracted.")
# Out:
# ✅ Both ZIPs extracted.

# %%
import os
import numpy as np
import torch
from PIL import Image
from tqdm import tqdm
from transformers import CLIPModel, CLIPProcessor

# %%
FRAME_SIZE = (224, 224)
FRAMES_PER_VIDEO = 16
FOLDER_LIST = [
    "/content/frames_unzip1",
    "/content/frames_unzip2"
]
OUTPUT_DIR = "/content/drive/MyDrive/video_vectorizer/clip4clip_embeddings"
os.makedirs(OUTPUT_DIR, exist_ok=True)


device = "cuda" if torch.cuda.is_available() else "cpu"
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
model.eval()

def load_clip_frames(folder_path, num_frames=FRAMES_PER_VIDEO):
    all_frames = sorted([
        os.path.join(folder_path, f)
        for f in os.listdir(folder_path)
        if f.lower().endswith((".jpg", ".png"))
    ])

    if len(all_frames) == 0:
        raise ValueError(f"No frames found in {folder_path}")

    indices = np.linspace(0, len(all_frames) - 1, num=min(num_frames, len(all_frames)), dtype=int)
    selected = [Image.open(all_frames[i]).convert("RGB").resize(FRAME_SIZE) for i in indices]

    while len(selected) < num_frames:
        selected.append(Image.new("RGB", FRAME_SIZE))  # padding with black frame

    return selected

def extract_clip4clip_video_embedding(images):
    inputs = processor(images=images, return_tensors="pt", padding=True).to(device)
    with torch.no_grad():
        outputs = model.get_image_features(**inputs)
    return outputs.mean(dim=0).cpu().numpy()  # (512,)


for root_folder in FOLDER_LIST:
    print(f"\nRoot folder: {root_folder}")

    top_level_folders = [f for f in os.listdir(root_folder) if os.path.isdir(os.path.join(root_folder, f))]

    for top_folder in top_level_folders:
        top_path = os.path.join(root_folder, top_folder)
        subfolders = [sf for sf in os.listdir(top_path) if os.path.isdir(os.path.join(top_path, sf))]

        print(f" Found {len(subfolders)} videos in: {top_folder}")

        for idx, sub_folder in enumerate(subfolders, start=1):
            folder_path = os.path.join(top_path, sub_folder)
            output_path = os.path.join(OUTPUT_DIR, f"{sub_folder}.npy")

            print(f"video {idx}/{len(subfolders)} → {sub_folder}")

            if os.path.exists(output_path):
                print(f" Skipping (already exists): {output_path}")
                continue

            try:
                frames = load_clip_frames(folder_path)
                emb = extract_clip4clip_video_embedding(frames)
                np.save(output_path, emb)
                print(f"Saved: {output_path}")
            except Exception as e:
                print(f"Skipped {folder_path}: {e}")
# Out:
# 📂 Root folder: /content/frames_unzip1
#  Found 1403 videos in: all_videos_frames
# video 1/1403 → 7431153975866477832_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7431153975866477832_frames.npy
# video 2/1403 → 7410671910494801169_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7410671910494801169_frames.npy
# video 3/1403 → 7455028385836748052_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7455028385836748052_frames.npy
# video 4/1403 → 7450507043993029895_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7450507043993029895_frames.npy
# video 5/1403 → 7436002221600312583_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7436002221600312583_frames.npy
# video 6/1403 → 7398671113494088961_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7398671113494088961_frames.npy
# video 7/1403 → 7456330597179428117_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7
frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7371090404734766343_frames.npy
# video 973/1063 → 7382983911980141831_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7382983911980141831_frames.npy
# video 974/1063 → 7365594427663863057_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7365594427663863057_frames.npy
# video 975/1063 → 7362851234543406337_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7362851234543406337_frames.npy
# video 976/1063 → 7315509312829377798_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7315509312829377798_frames.npy
# video 977/1063 → 7398436338485218567_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7398436338485218567_frames.npy
# video 978/1063 → 7329270003671321857_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7329270003671321857_frames.npy
# video 979/1063 → 7351565609546550546_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7351565609546550546_frames.npy
# video 980/1063 → 7333212360787774738_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7333212360787774738_frames.npy
# video 981/1063 → 7333924540340358407_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7333924540340358407_frames.npy
# video 982/1063 → 7424968304361491713_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7424968304361491713_frames.npy
# video 983/1063 → 7384765324270390535_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7384765324270390535_frames.npy
# video 984/1063 → 7353356223489527047_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7353356223489527047_frames.npy
# video 985/1063 → 7459832361237171464_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7459832361237171464_frames.npy
# video 986/1063 → 7410665751469788417_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7410665751469788417_frames.npy
# video 987/1063 → 7330617197502467336_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7330617197502467336_frames.npy
# video 988/1063 → 7364114548837584144_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7364114548837584144_frames.npy
# video 989/1063 → 7391836993715473682_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7391836993715473682_frames.npy
# video 990/1063 → 7460606084034743570_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7460606084034743570_frames.npy
# video 991/1063 → 7385929323489938693_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7385929323489938693_frames.npy
# video 992/1063 → 7386999848223968520_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7386999848223968520_frames.npy
# video 993/1063 → 7395814421521648913_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7395814421521648913_frames.npy
# video 994/1063 → 7361320282948242695_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7361320282948242695_frames.npy
# video 995/1063 → 7342093763575172360_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7342093763575172360_frames.npy
# video 996/1063 → 7436036738604141832_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7436036738604141832_frames.npy
# video 997/1063 → 7339932005963992328_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7339932005963992328_frames.npy
# video 998/1063 → 7315744553049312520_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7315744553049312520_frames.npy
# video 999/1063 → 7388975639577070864_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7388975639577070864_frames.npy
# video 1000/1063 → 7342856464421211410_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7342856464421211410_frames.npy
# video 1001/1063 → 7363304165939907858_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7363304165939907858_frames.npy
# video 1002/1063 → 7379312957697608978_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7379312957697608978_frames.npy
# video 1003/1063 → 7364438543449591058_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7364438543449591058_frames.npy
# video 1004/1063 → 7397374974153018644_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7397374974153018644_frames.npy
# video 1005/1063 → 7412050622863707408_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7412050622863707408_frames.npy
# video 1006/1063 → 7306581397618183426_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7306581397618183426_frames.npy
# video 1007/1063 → 7414408368502082824_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7414408368502082824_frames.npy
# video 1008/1063 → 7405317891823914241_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7405317891823914241_frames.npy
# video 1009/1063 → 7289694645255212295_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7289694645255212295_frames.npy
# video 1010/1063 → 7344794660017097985_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7344794660017097985_frames.npy
# video 1011/1063 → 7295726737005104392_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7295726737005104392_frames.npy
# video 1012/1063 → 7342550256321596674_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7342550256321596674_frames.npy
# video 1013/1063 → 7395775016584957205_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7395775016584957205_frames.npy
# video 1014/1063 → 7410203527168953607_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7410203527168953607_frames.npy
# video 1015/1063 → 7380279891666816264_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7380279891666816264_frames.npy
# video 1016/1063 → 7397714542052052245_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7397714542052052245_frames.npy
# video 1017/1063 → 7338811078584945927_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7338811078584945927_frames.npy
# video 1018/1063 → 7455448825679973650_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7455448825679973650_frames.npy
# video 1019/1063 → 7371459037759540488_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7371459037759540488_frames.npy
# video 1020/1063 → 7459999089447439638_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7459999089447439638_frames.npy
# video 1021/1063 → 7307687314728209671_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7307687314728209671_frames.npy
# video 1022/1063 → 7361757701543693585_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7361757701543693585_frames.npy
# video 1023/1063 → 7450621452555930898_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7450621452555930898_frames.npy
# video 1024/1063 → 7292536160209931552_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7292536160209931552_frames.npy
# video 1025/1063 → 7329624491124870418_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7329624491124870418_frames.npy
# video 1026/1063 → 7350068873409989896_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7350068873409989896_frames.npy
# video 1027/1063 → 7426848232145161473_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7426848232145161473_frames.npy
# video 1028/1063 → 7433122668301290760_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7433122668301290760_frames.npy
# video 1029/1063 → 7415118362134580488_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7415118362134580488_frames.npy
# video 1030/1063 → 7306908795249134855_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7306908795249134855_frames.npy
# video 1031/1063 → 7365887187268734215_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7365887187268734215_frames.npy
# video 1032/1063 → 7382982010689555720_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7382982010689555720_frames.npy
# video 1033/1063 → 7392205626031574277_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7392205626031574277_frames.npy
# video 1034/1063 → 7407054869779025159_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7407054869779025159_frames.npy
# video 1035/1063 → 7363342051863366918_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7363342051863366918_frames.npy
# video 1036/1063 → 7365170616091053320_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7365170616091053320_frames.npy
# video 1037/1063 → 7428549700250356999_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7428549700250356999_frames.npy
# video 1038/1063 → 7335936398802963720_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7335936398802963720_frames.npy
# video 1039/1063 → 7456803580893269256_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7456803580893269256_frames.npy
# video 1040/1063 → 7350700541590162696_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7350700541590162696_frames.npy
# video 1041/1063 → 7362174964377685255_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7362174964377685255_frames.npy
# video 1042/1063 → 7418669427480071442_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7418669427480071442_frames.npy
# video 1043/1063 → 7365899117156945160_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7365899117156945160_frames.npy
# video 1044/1063 → 7310366695682493728_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7310366695682493728_frames.npy
# video 1045/1063 → 7369680685537250576_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7369680685537250576_frames.npy
# video 1046/1063 → 7364026793554185480_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7364026793554185480_frames.npy
# video 1047/1063 → 7454192434902289672_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7454192434902289672_frames.npy
# video 1048/1063 → 7337022435075607826_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7337022435075607826_frames.npy
# video 1049/1063 → 7380442083779251474_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7380442083779251474_frames.npy
# video 1050/1063 → 7345893445233315074_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7345893445233315074_frames.npy
# video 1051/1063 → 7407451998116744469_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7407451998116744469_frames.npy
# video 1052/1063 → 7368445691238173969_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7368445691238173969_frames.npy
# video 1053/1063 → 7406066587070975240_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7406066587070975240_frames.npy
# video 1054/1063 → 7454083712997772562_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7454083712997772562_frames.npy
# video 1055/1063 → 7450701700815555842_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7450701700815555842_frames.npy
# video 1056/1063 → 7388600888039836944_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7388600888039836944_frames.npy
# video 1057/1063 → 7356628438884699408_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7356628438884699408_frames.npy
# video 1058/1063 → 7354120921919032592_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7354120921919032592_frames.npy
# video 1059/1063 → 7383595406149586184_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7383595406149586184_frames.npy
# video 1060/1063 → 7449733284260531474_frames
# ⏩ Skipping (already exists): /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7449733284260531474_frames.npy
# video 1061/1063 → 7343358751073766663_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7343358751073766663_frames.npy
# video 1062/1063 → 7333683842550746376_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7333683842550746376_frames.npy
# video 1063/1063 → 7349507112038321426_frames
# ✅ Saved: /content/drive/MyDrive/video_vectorizer/clip4clip_embeddings/7349507112038321426_frames.npy
